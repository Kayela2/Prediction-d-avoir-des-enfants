# %%
import pandas as pd
import pyreadstat
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

print("Toutes les bibliothèques sont chargées ✓")
# Out:
# Toutes les bibliothèques sont chargées ✓

# %%
# Chargement du fichier EDSC Cameroun
df, meta = pyreadstat.read_sav("../CMIR71FL.SAV")

print(f"Lignes    : {df.shape[0]:,}")
print(f"Colonnes  : {df.shape[1]:,}")
print("\nAperçu des premières colonnes :")
print(df.columns[:20].tolist())
# Out:
# ---------------------------------------------------------------------------
# PyreadstatError                           Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Chargement du fichier EDSC Cameroun
# ----> 2 df, meta = pyreadstat.read_sav("../CMIR71FL.SAV")
#       3
#       4 print(f"Lignes    : {df.shape[0]:,}")
#       5 print(f"Colonnes  : {df.shape[1]:,}")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pyreadstat\pyreadstat.py:687, in read_sav(filename_path, metadataonly, dates_as_pandas_datetime, apply_value_formats, formats_as_category, formats_as_ordered_category, encoding, usecols, user_missing, disable_datetime_conversion, row_limit, row_offset, output_format, extra_datetime_formats, extra_date_formats, extra_time_formats)
#     625 r"""
#     626 Read a SPSS sav or zsav (compressed) files
#     627
#    (...)    683         object with metadata. Look at the documentation for more information.
#     684 """
# ...

# %%
import os

# Voir où on est actuellement
print("Dossier actuel :", os.getcwd())
print("\nFichiers dans EDS-Cameroon :")

# Chercher tous les fichiers .SAV
for root, dirs, files in os.walk("C:\\Users\\FTAB TECH\\EDS-Cameroon"):
    for file in files:
        if file.endswith(".SAV") or file.endswith(".sav"):
            print(os.path.join(root, file))
# Out:
# Dossier actuel : C:\Users\FTAB TECH\EDS-Cameroon
#
# Fichiers dans EDS-Cameroon :
# C:\Users\FTAB TECH\EDS-Cameroon\CMIR71FL.SAV
# C:\Users\FTAB TECH\EDS-Cameroon\data\CMIR71FL.SAV
# C:\Users\FTAB TECH\EDS-Cameroon\DHS-Indicators-R-main\Chap06_FF\CMHR71FL.SAV
# C:\Users\FTAB TECH\EDS-Cameroon\Frequece_Fecond\EDS-Cameroon\CMHR71FL.SAV
# C:\Users\FTAB TECH\EDS-Cameroon\Frequece_Fecond\EDS-Cameroon\DHS-Indicators-R-main\Chap06_FF\CMHR71FL.SAV
# C:\Users\FTAB TECH\EDS-Cameroon\Frequece_Fecond\EDS-Cameroon\DHS-Indicators-R-main\Chap16_AM\CMIR71FL.SAV
# C:\Users\FTAB TECH\EDS-Cameroon\venv\Lib\site-packages\scipy\io\tests\data\array_float32_1d.sav
# C:\Users\FTAB TECH\EDS-Cameroon\venv\Lib\site-packages\scipy\io\tests\data\array_float32_2d.sav
# C:\Users\FTAB TECH\EDS-Cameroon\venv\Lib\site-packages\scipy\io\tests\data\array_float32_3d.sav
# C:\Users\FTAB TECH\EDS-Cameroon\venv\Lib\site-packages\scipy\io\tests\data\array_float32_4d.sav
# ...

# %%
# Chemin absolu vers le fichier
chemin = r"C:\Users\FTAB TECH\EDS-Cameroon\data\CMIR71FL.SAV"

# Chargement
df, meta = pyreadstat.read_sav(chemin)

print(f"Lignes    : {df.shape[0]:,}")
print(f"Colonnes  : {df.shape[1]:,}")
print(f"\nAperçu des 10 premières colonnes :")
print(df.columns[:10].tolist())
# Out:
# Lignes    : 14,677
# Colonnes  : 5,102
#
# Aperçu des 10 premières colonnes :
# ['CASEID', 'V000', 'V001', 'V002', 'V003', 'V004', 'V005', 'V006', 'V007', 'V008']
